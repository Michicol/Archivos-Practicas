# %%
import os
import sys

sys.path.append("/home/michicol/Desktop/Practicas Profesionales/build")

import wishart_module as woe
import numpy as np
import matplotlib.pyplot as plt

# %%
WOE = woe.calcular_wishart(1000,10000)
#WOE

# %%
WOE = np.array(WOE)

# %%
Evals = np.linalg.eigvalsh(WOE)

# %%
plt.figure()

plt.hist(Evals,bins=50,density=True,linewidth=0.5, edgecolor="white")

plt.show()
